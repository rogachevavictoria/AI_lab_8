# %%
import pandas as pd
import numpy as np
import datetime as dt
import dateutil as du

# %%
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Fremont_Bridge.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# Date
# 2019-01-31 23:00:00                           7.0                           6.0
# 2019-01-31 22:00:00                          13.0                          16.0
# 2019-01-31 21:00:00                          18.0                          27.0
# 2019-01-31 20:00:00                          32.0                          33.0
# 2019-01-31 19:00:00                          40.0                          94.0

# %%
data.columns=['East','West']
data['Total'] = data['East'] + data['West']
data
# Out:
#                      East  West  Total
# Date
# 2019-01-31 23:00:00   7.0   6.0   13.0
# 2019-01-31 22:00:00  13.0  16.0   29.0
# 2019-01-31 21:00:00  18.0  27.0   45.0
# 2019-01-31 20:00:00  32.0  33.0   65.0
# 2019-01-31 19:00:00  40.0  94.0  134.0
# ...                   ...   ...    ...
# 2012-10-03 04:00:00   6.0   1.0    7.0
# 2012-10-03 03:00:00   2.0   3.0    5.0
# 2012-10-03 02:00:00   1.0   1.0    2.0
# 2012-10-03 01:00:00   4.0   6.0   10.0
# 2012-10-03 00:00:00   4.0   9.0   13.0
#
# [55488 rows x 3 columns]

# %%
weekly = data.resample('W').sum()
weekly.plot()

# %%
by_time = data.groupby(data.index.time).mean()
by_time.head()
# Out:
#               East      West      Total
# 00:00:00  5.072232  6.712370  11.784602
# 01:00:00  2.820934  3.372837   6.193772
# 02:00:00  2.026008  2.102297   4.128305
# 03:00:00  1.582612  1.431228   3.013841
# 04:00:00  3.539360  3.050606   6.589965

# %%
hourly_ticks = 4 * 60 * 60 * np.arange(6)

# %%
by_time.plot(xticks=hourly_ticks)

# %%
by_weekday = data_2013.groupby(data_2013.index.dayofweek).mean()
by_weekday
# Out:
#            East       West       Total
# Date
# 0     62.290865  60.334936  122.625801
# 1     65.583333  63.307390  128.890723
# 2     65.338141  63.435096  128.773237
# 3     61.435897  58.561699  119.997596
# 4     57.992777  55.295345  113.288122
# 5     36.093750  30.471955   66.565705
# 6     33.903846  27.471154   61.375000

# %%
by_weekday.index = ['Mon','Tues','Wed','Thurs','Fri','Sat','Sun']
by_weekday.plot()

# %%
by_weekday[5:]
# Out:
#           East       West      Total
# Sat  36.093750  30.471955  66.565705
# Sun  33.903846  27.471154  61.375000

# %%
hourly_ticks_2 = 2 * 60 * 60 * np.arange(12)
print(hourly_ticks_2[5:12])
# Out:
# [36000 43200 50400 57600 64800 72000 79200]

# %%
data_2013 = data['2013']
data_2013
# Out:
#                      East  West  Total
# Date
# 2013-12-31 23:00:00  17.0   5.0   22.0
# 2013-12-31 22:00:00  10.0   4.0   14.0
# 2013-12-31 21:00:00   5.0   6.0   11.0
# 2013-12-31 20:00:00  13.0  23.0   36.0
# 2013-12-31 19:00:00  21.0  17.0   38.0
# ...                   ...   ...    ...
# 2013-01-01 04:00:00   2.0   2.0    4.0
# 2013-01-01 03:00:00   2.0   4.0    6.0
# 2013-01-01 02:00:00   8.0   8.0   16.0
# 2013-01-01 01:00:00   9.0  12.0   21.0
# 2013-01-01 00:00:00   2.0   5.0    7.0
#
# [8760 rows x 3 columns]
